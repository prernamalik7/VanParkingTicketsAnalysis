# %%
#Import all necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import re
import folium
from folium.plugins import HeatMap
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time
from matplotlib.colors import ListedColormap

# Set the display format for floating point numbers
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# <h3>Load & prepare data for analysis

# %%
# Load FULL parking ticket data & StreetCentreline_HundredBlock data

# Specify the path to your Parquet file
file_path = 'parking-tickets.parquet'

# Load the Parquet file into a DataFrame
full_parking_tickets = pd.read_parquet(file_path)

# Display the DataFrame
print(full_parking_tickets)

# Load street data
street_data_filepath = 'StreetCentreline_HundredBlock.xlsx'
street_data = pd.read_excel(street_data_filepath)
# Out:
#          block        street   entrydate  bylaw      section status  \
# 0         2000    W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 1         2000    W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 2         5900     EAST BLVD  2020-01-04   2849         21.1     IS
# 3          400    W 64TH AVE  2020-01-04   2849      17.6(B)     IS
# 4          500     ABBOTT ST  2020-01-04   2849         21.1     IS
# ...        ...           ...         ...    ...          ...    ...
# 1803275    100  NATIONAL AVE  2024-01-31   2849      17.6(E)     IS
# 1803276    600    W 14TH AVE  2022-02-10   2849      17.6(B)     IS
# 1803277   1100    E 11TH AVE  2022-03-09   2849  17.5(C)(ii)     IS
# 1803278    200    E 14TH AVE  2024-05-24   2849      19.1(G)     IS
# 1803279   2500       PINE ST  2021-08-31   2952  5(4)(A)(ii)     IS
#
#                                             infractiontext  year    bi_id
# 0        PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649772
# 1        PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649775
# 2                                   STOP IN PASSENGER ZONE  2020  3649778
# 3        PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2020  3649781
# 4                                   STOP IN PASSENGER ZONE  2020  3649786
# ...                                                    ...   ...      ...
# 1803275                                               None  2024  5513502
# 1803276                                               None  2022  5513504
# 1803277                                               None  2022  5513505
# 1803278                                               None  2024  5513507
# 1803279                                               None  2021  5513509
#
# [1803280 rows x 9 columns]

# %%
#print a sample

print(full_parking_tickets.head(20))
print(full_parking_tickets.shape)
print(street_data.head(20))
print(street_data.shape)
# Out:
#     block            street   entrydate  bylaw      section status  \
# 0    2000        W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 1    2000        W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 2    5900         EAST BLVD  2020-01-04   2849         21.1     IS
# 3     400        W 64TH AVE  2020-01-04   2849      17.6(B)     IS
# 4     500         ABBOTT ST  2020-01-04   2849         21.1     IS
# 5       0         POWELL ST  2020-01-04   2849      17.2(M)     IS
# 6     500        SEYMOUR ST  2020-01-04   2849         21.1     IS
# 7     800       RICHARDS ST  2020-01-04   2849      17.6(F)     VA
# 8    2200         PARKER ST  2020-01-04   2849      17.6(F)     VA
# 9    2600        TRIUMPH ST  2020-01-04   2849      17.6(F)     VA
# 10   5800     COMMERCIAL ST  2020-01-04   2849      17.6(F)     VA
# 11   4800  PRINCE ALBERT ST  2020-01-04   2849      17.6(F)     VA
# 12    800        E 16TH AVE  2020-01-04   2849      17.6(F)     VA
# 13   4100      ST GEORGE ST  2020-01-04   2849      17.6(F)     VA
# 14   3200         W 7TH AVE  2020-01-04   2849      17.6(F)     VA
# 15   3000         W 7TH AVE  2020-01-04   2849  18.1(B)(ii)     IS
# 16    800        E 16TH AVE  2020-01-04   2849      17.6(F)     IS
# 17   5300         QUEBEC ST  2020-01-04   2849      17.6(F)     IS
# 18   1400        W 59TH AVE  2020-01-04   2849      17.6(F)     IS
# 19    400         KEEFER ST  2020-01-04   2849      17.6(B)     IS
#
#                                        infractiontext  year    bi_id
# 0   PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649772
# 1   PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649775
# 2                              STOP IN PASSENGER ZONE  2020  3649778
# 3   PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2020  3649781
# 4                              STOP IN PASSENGER ZONE  2020  3649786
# 5   STOP ON ANY PORTION OF A STREET THAT IS DESIGN...  2020  3649788
# 6                              STOP IN PASSENGER ZONE  2020  3649790
# 7   PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649791
# 8   PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649793
# 9   PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649796
# 10  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649799
# 11  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649800
# 12  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649802
# 13  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649803
# 14  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649808
# 15  STOP OR PARK OTHER THAN HEADED IN THE DIRECTIO...  2020  3649809
# 16  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649815
# 17  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649817
# 18  PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2020  3649818
# 19  PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2020  3649823
# (1803280, 9)
#     OBJECTID  COV_SOURCE_KEY          LASTUPDATE  \
# 0          1           42835 2024-04-09 07:02:44
# 1          2           42835 2024-04-09 07:02:44
# 2          3          209983 2021-04-06 21:05:13
# 3          4          209983 2021-04-06 21:05:13
# 4          5          212046 2024-04-10 18:51:01
# 5          6          209991 2022-06-15 07:10:31
# 6          7          209991 2022-06-15 07:10:31
# 7          8          212060 2024-04-10 18:51:00
# 8          9           40075 2023-08-18 07:03:59
# 9         10           35811 2023-08-18 07:04:00
# 10        11           32757 2021-09-28 07:01:33
# 11        12           33088 2021-09-28 07:01:32
# 12        13          209987 2021-04-06 21:05:12
# 13        14           78662 2020-04-27 14:56:11
# 14        15           33031 2023-08-18 07:03:23
# 15        16           33031 2023-08-18 07:03:23
# 16        17           80753 2010-11-29 18:28:44
# 17        18           81092 2010-11-29 18:28:45
# 18        19           78238 2010-11-29 18:28:37
# 19        20           81213 2010-11-29 18:28:46
#
#                                      UNIT_DESCRIPTION  OWNEDBY STREET_CLASS  \
# 0         QUESNEL DRIVE from W 21ST AV to VALDEZ ROAD    COVAV       Street
# 1         QUESNEL DRIVE from W 21ST AV to VALDEZ ROAD    COVAV       Street
# 2                                             GORE AV    COVAV       Street
# 3                                             GORE AV    COVAV       Street
# 4                                      Unnamed Street  Private       Street
# 5              NATIONAL AV from GORE AV to UNNAMED ST    COVAV       Street
# 6              NATIONAL AV from GORE AV to UNNAMED ST    COVAV       Street
# 7                                        Unnamed Road  Private       Street
# 8              NATIONAL AV from STATION ST to GORE AV    COVAV       Street
# 9          STATION ST from NATIONAL AV to TERMINAL AV    COVAV       Street
# 10         NATIONAL AV from UNNAMED ST to THORNTON ST    COVAV       Street
# 11            STATION ST from PRIOR ST to NATIONAL AV    COVAV       Street
# 12                                            GORE AV    COVAV       Street
# 13  L/E of GRANVILLE ST from W 8TH AV to W BROADWA...    COVAV         Lane
# 14            RENFREW ST from RENFREW ST to E 12TH AV    COVAV       Street
# 15            RENFREW ST from RENFREW ST to E 12TH AV    COVAV       Street
# 16                                          W 14TH AV    COVAV         Lane
# 17                                          W 11TH AV    COVAV         Lane
# 18                                          W 11TH AV    COVAV         Lane
# 19                                          W 14TH AV    COVAV         Lane
#
#    DISPOSITION_STATE      SEGTYPE      MAINTENANCE         INSTALLDATE  ...  \
# 0         In Service    Collector  COV Engineering 1900-01-01 08:00:00  ...
# 1         In Service    Collector  COV Engineering 1900-01-01 08:00:00  ...
# 2         In Service  Residential  COV Engineering 2100-01-01 08:00:00  ...
# 3         In Service  Residential  COV Engineering 2100-01-01 08:00:00  ...
# 4         In Service  Residential          Private 2100-01-01 08:00:00  ...
# 5         In Service  Residential  COV Engineering 2100-01-01 08:00:00  ...
# 6         In Service  Residential  COV Engineering 2100-01-01 08:00:00  ...
# 7         In Service  Residential          Private 2100-01-01 08:00:00  ...
# 8         In Service  Residential  COV Engineering 1900-01-01 08:00:00  ...
# 9         In Service  Residential  COV Engineering 1924-01-01 08:00:00  ...
# 10        In Service  Residential  COV Engineering 1900-01-01 08:00:00  ...
# 11        In Service  Residential  COV Engineering 1900-01-01 08:00:00  ...
# 12        In Service  Residential  COV Engineering 2100-01-01 08:00:00  ...
# 13        In Service  Residential  COV Engineering                 NaT  ...
# 14        In Service     Arterial  COV Engineering 1900-01-01 08:00:00  ...
# 15        In Service     Arterial  COV Engineering 1900-01-01 08:00:00  ...
# 16        In Service        blank  COV Engineering                 NaT  ...
# 17        In Service        blank  COV Engineering                 NaT  ...
# 18        In Service        blank  COV Engineering                 NaT  ...
# 19        In Service        blank  COV Engineering                 NaT  ...
#
#    LOW_ADDRESS TO_STREET  LAST_UPDATED_BY  MATERIAL  DIRECTION  \
# 0      3700.00   1989.00     ENHANMGETASK   Asphalt      blank
# 1      3700.00   1989.00     ENHANMGETASK   Asphalt      blank
# 2       900.00   1987.00            enpbn       NaN        NaN
# 3       900.00   1987.00            enpbn       NaN        NaN
# 4       200.00   1987.00            ENAFP       NaN        NaN
# 5       200.00   1987.00     ENHANMGETASK   Asphalt      blank
# 6       200.00   1987.00     ENHANMGETASK   Asphalt      blank
# 7       900.00   1729.00            ENAFP       NaN        NaN
# 8       200.00   1453.00     ENHANMGETASK  Concrete      blank
# 9      1100.00   1949.00     ENHANMGETASK   Asphalt      blank
# 10      200.00   1956.00     ENHANMGETASK     blank      blank
# 11      900.00   1729.00     ENHANMGETASK     blank      blank
# 12      900.00   1729.00            enpbn       NaN        NaN
# 13     2400.00   1581.00            enpbn   Asphalt      blank
# 14     2600.00   1305.00     ENHANMGETASK   Asphalt      blank
# 15     2600.00   1305.00     ENHANMGETASK   Asphalt      blank
# 16     2000.00   1038.00            enmxp   Asphalt        NaN
# 17     1900.00   1636.00            enmxp   Asphalt        NaN
# 18     2000.00   1038.00            enmxp   Asphalt        NaN
# 19     2100.00   2145.00            enmxp   Asphalt        NaN
#
#                   HBLOCK  FROM_STREET_LONG  TO_STREET_LONG  \
# 0     3700 QUESNEL DRIVE         W 21ST AV     VALDEZ ROAD
# 1     3700 QUESNEL DRIVE         W 21ST AV     VALDEZ ROAD
# 2       900-1000 GORE AV          PRIOR ST      UNNAMED ST
# 3       900-1000 GORE AV          PRIOR ST      UNNAMED ST
# 4     200-300 UNNAMED ST           GORE AV      UNNAMED ST
# 5    200-400 NATIONAL AV           GORE AV      UNNAMED ST
# 6    200-400 NATIONAL AV           GORE AV      UNNAMED ST
# 7    900-1000 UNNAMED ST        UNNAMED ST     NATIONAL AV
# 8        200 NATIONAL AV        STATION ST         GORE AV
# 9   1100-1200 STATION ST       NATIONAL AV     TERMINAL AV
# 10   200-400 NATIONAL AV        UNNAMED ST     THORNTON ST
# 11   900-1000 STATION ST          PRIOR ST     NATIONAL AV
# 12      900-1000 GORE AV        UNNAMED ST     NATIONAL AV
# 13     2400 GRANVILLE ST          W 8TH AV            LANE
# 14  2600-2700 RENFREW ST        RENFREW ST       E 12TH AV
# 15  2600-2700 RENFREW ST        RENFREW ST       E 12TH AV
# 16        2000 W 14TH AV          MAPLE ST      ARBUTUS ST
# 17        1900 W 11TH AV        CYPRESS ST        MAPLE ST
# 18        2000 W 11TH AV               NaN      ARBUTUS ST
# 19        2100 W 14TH AV        ARBUTUS ST          YEW ST
#
#            NEIGHBORHOOD SHAPE_Length
# 0     Dunbar-Southlands        37.96
# 1     Dunbar-Southlands        89.80
# 2            Strathcona        33.92
# 3            Strathcona       126.79
# 4            Strathcona        78.25
# 5            Strathcona       105.01
# 6            Strathcona       166.16
# 7            Strathcona       112.63
# 8            Strathcona        44.44
# 9            Strathcona       259.85
# 10           Strathcona       181.83
# 11           Strathcona       205.28
# 12           Strathcona        77.65
# 13             Fairview        48.13
# 14  Renfrew-Collingwood        73.58
# 15  Renfrew-Collingwood        54.24
# 16            Kitsilano       174.59
# 17            Kitsilano       174.83
# 18            Kitsilano        48.16
# 19            Kitsilano       172.42
#
# [20 rows x 27 columns]
# (28115, 27)

# %%
# Filter relevant columns from street data
street_data_filtered = street_data[['STREET_NAME', 'LOW_ADDRESS', 'HIGH_ADDRESS', 'NEIGHBORHOOD', 'HBLOCK']]

# %%
street_data_filtered.shape
# Out:
# (28115, 5)

# %% [markdown]
# <h3>Checking Data Structure and Basic Information:

# %%
if full_parking_tickets is not None:
    # Display basic information about the dataframe
    print(full_parking_tickets.info())
    print(full_parking_tickets.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1803280 entries, 0 to 1803279
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   block           int64
#  1   street          object
#  2   entrydate       object
#  3   bylaw           int64
#  4   section         object
#  5   status          object
#  6   infractiontext  object
#  7   year            object
#  8   bi_id           int64
# dtypes: int64(3), object(6)
# memory usage: 123.8+ MB
# None
#    block      street   entrydate  bylaw      section status  \
# 0   2000  W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 1   2000  W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 2   5900   EAST BLVD  2020-01-04   2849         21.1     IS
# 3    400  W 64TH AVE  2020-01-04   2849      17.6(B)     IS
# 4    500   ABBOTT ST  2020-01-04   2849         21.1     IS
#
#                                       infractiontext  year    bi_id
# 0  PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649772
# 1  PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649775
# 2                             STOP IN PASSENGER ZONE  2020  3649778
# 3  PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2020  3649781
# 4                             STOP IN PASSENGER ZONE  2020  3649786

# %% [markdown]
# <h3>Inspecting Numerical Columns

# %%
# Describe the numerical columns
full_parking_tickets.describe()
# Out:
#            block      bylaw      bi_id
# count 1803280.00 1803280.00 1803280.00
# mean     1486.54    2953.11 4590970.65
# std      1951.83     673.77  576586.91
# min         0.00    2849.00   59169.00
# 25%       600.00    2849.00 4158522.75
# 50%      1100.00    2952.00 4610232.50
# 75%      1900.00    2952.00 5068702.25
# max     99900.00   13323.00 5526982.00

# %% [markdown]
# <h3>Inspecting Categorical Columns

# %%
# Describe the categorical columns
print(full_parking_tickets.describe(include=['object']))
# Out:
#              street   entrydate      section   status  \
# count       1803280     1803280      1803280  1803280
# unique          948        1633          125        4
# top     RICHARDS ST  2024-06-12  5(4)(A)(ii)       IS
# freq          88214        1725       678807  1568039
#
#                                            infractiontext     year
# count                                              847410  1803280
# unique                                                129        5
# top     PARK IN A METERED SPACE IF THE PARKING METER H...     2023
# freq                                               357434   424371

# %%
# Value counts for categorical columns
print(full_parking_tickets['street'].value_counts())
print(full_parking_tickets['entrydate'].value_counts())
print(full_parking_tickets['bylaw'].value_counts())
print(full_parking_tickets['section'].value_counts())
print(full_parking_tickets['status'].value_counts())
print(full_parking_tickets['infractiontext'].value_counts())
# Out:
# RICHARDS ST        88214
# HOMER ST           72542
# ROBSON ST          61416
# W 4TH AVE          56894
# W 8TH AVE          47111
#                    ...
# BURKHOLDER DR P        1
# GLENGYLE ST            1
# CAVERSHAM CT P         1
# SKEENA ST N            1
# MARLIN QUAY P          1
# Name: street, Length: 948, dtype: int64
# 2024-06-12    1725
# 2024-06-25    1716
# 2021-07-07    1691
# 2024-04-16    1681
# 2024-06-06    1668
#               ...
# 2023-08-23      11
# 2023-08-25      11
# 2023-08-22      11
# 2020-01-15       2
# 2024-01-19       1
# Name: entrydate, Length: 1633, dtype: int64
# 2952     915807
# 2849     876775
# 12086      7463
# 9978       1728
# 9344        910
# 13323       597
# Name: bylaw, dtype: int64
# 5(4)(A)(ii)    678807
# 5(4)(B)        234462
# 17.6(B)        161747
# 17.1(B)        158363
# 17.6(E)         95357
#                 ...
# 8.2(F)              1
# 17.2(D)             1
# 8.2(A)(II)          1
# 17.2(A)             1
# 8.2(A)(I)           1
# Name: section, Length: 125, dtype: int64
# IS    1568039
# VA     217541
# WR      14519
# VS       3181
# Name: status, dtype: int64
# PARK IN A METERED SPACE IF THE PARKING METER HEAD DISPLAYS FOUR FLASHING ZEROS IN A WINDOW                                                 357434
# PARK IN A METERED SPACE IF THE TIME RECORDED BY THE OPERATOR UNDER THE PAY BY PHONE OR PAY BY LICENCE PLATE OPTION HAS EXPIRED              85021
# PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICTS PARKING, EXCEPT IN ACCORDANCE WITH SUCH RESTRICTION                                         71946
# STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING                                                                                     71097
# STOP ON ANY STREET OR PORTION OF A STREET DESIGNATED AS A PRIORITY CONGESTION MANAGEMENT ROADWAY DURING THE TIME STOPPING IS PROHIBITED     43083
#                                                                                                                                             ...
# WATER GOLF COURSE FAIRWAY OUTSIDE PERMITTED NUMBER OF DAYS - STAGE 2                                                                            1
# PARK IN A METERED SPACE IF THE TIME RECORDED BY THE OPERATOR UNDER THE PAY BY PHONE OR PAY BY LICENCE PLATE OPTION HAS EXPIRED.                 1
# STOP WITHIN 6 METRES OF THE APPROACH SIDE OF A STOP SIGN.                                                                                       1
# A PERSON WHO IS GUILTY OF AN OFFENCE AGAINST THIS BY-LAW, AND LIABLE TO THE PENALTIES IMPOSED UNDER THIS SECTION                                1
# STOP IN FRONT OF OR WITHIN 1.5 METRES OFTHE NEAREST SIDE OF A PRIVATE ROAD, BOULEVARD CROSSING OR SIDEWALK CROSSING.                            1
# Name: infractiontext, Length: 129, dtype: int64

# %% [markdown]
# <h3>Check for null values in the data

# %%
# Check for null values in tickets data
print(full_parking_tickets.isnull().sum())
# Out:
# block                  0
# street                 0
# entrydate              0
# bylaw                  0
# section                0
# status                 0
# infractiontext    955870
# year                   0
# bi_id                  0
# dtype: int64

# %% [markdown]
# <h4>------- Handling missing values:

# %%
# filling missing 'InfractionText' values with 'Unknown'
full_parking_tickets['infractiontext'].fillna('Unknown', inplace=True)

# Confirm no missing values remain
null_values_after = full_parking_tickets.isnull().sum()
print("Null values after cleaning:")
print(null_values_after)
# Out:
# Null values after cleaning:
# block             0
# street            0
# entrydate         0
# bylaw             0
# section           0
# status            0
# infractiontext    0
# year              0
# bi_id             0
# dtype: int64

# %% [markdown]
# <h3>Data Type Conversion:  converting EntryDate column to datetime type.

# %%
# Convert 'EntryDate' to datetime
full_parking_tickets['entrydate'] = pd.to_datetime(full_parking_tickets['entrydate'], errors='coerce')
    
# Confirm the data types
print(full_parking_tickets.dtypes)
# Out:
# block                      int64
# street                    object
# entrydate         datetime64[ns]
# bylaw                      int64
# section                   object
# status                    object
# infractiontext            object
# year                      object
# bi_id                      int64
# dtype: object

# %% [markdown]
# <h3>Data Quality Check
#
# Perform additional quality checks to ensure the data is clean and ready for analysis.

# %%
# Standardize street names in both datasets
street_data_filtered['STREET_NAME'] = street_data_filtered['STREET_NAME'].str.upper().str.strip()
full_parking_tickets['street'] = full_parking_tickets['street'].str.upper().str.strip()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Check for the number of duplicate rows
duplicate_rows = full_parking_tickets.duplicated()
num_duplicates = duplicate_rows.sum()
print(f"Number of duplicate rows: {num_duplicates}")

# Remove duplicate entries if any
full_parking_tickets.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
# Check for any remaining inconsistencies or anomalies
print("Data quality checks:")
print(full_parking_tickets.describe(include='all'))
# Out:
# Data quality checks:
#             block       street            entrydate      bylaw      section  \
# count  1803280.00      1803280              1803280 1803280.00      1803280
# unique        nan          948                 1633        nan          125
# top           nan  RICHARDS ST  2024-06-12 00:00:00        nan  5(4)(A)(ii)
# freq          nan        88214                 1725        nan       678807
# first         nan          NaN  2020-01-02 00:00:00        nan          NaN
# last          nan          NaN  2024-06-30 00:00:00        nan          NaN
# mean      1486.54          NaN                  NaN    2953.11          NaN
# std       1951.83          NaN                  NaN     673.77          NaN
# min          0.00          NaN                  NaN    2849.00          NaN
# 25%        600.00          NaN                  NaN    2849.00          NaN
# 50%       1100.00          NaN                  NaN    2952.00          NaN
# 75%       1900.00          NaN                  NaN    2952.00          NaN
# max      99900.00          NaN                  NaN   13323.00          NaN
#
#          status infractiontext     year      bi_id
# count   1803280        1803280  1803280 1803280.00
# unique        4            130        5        nan
# top          IS        Unknown     2023        nan
# freq    1568039         955870   424371        nan
# first       NaN            NaN      NaN        nan
# last        NaN            NaN      NaN        nan
# mean        NaN            NaN      NaN 4590970.65
# std         NaN            NaN      NaN  576586.91
# min         NaN            NaN      NaN   59169.00
# 25%         NaN            NaN      NaN 4158522.75
# 50%         NaN            NaN      NaN 4610232.50
# 75%         NaN            NaN      NaN 5068702.25
# max         NaN            NaN      NaN 5526982.00

# %% [markdown]
# <h2>Data Loading & Cleaning Combined

# %%
# Specify the path to your Parquet file
file_path = 'parking-tickets.parquet'

# Load the Parquet file into a DataFrame
full_parking_tickets = pd.read_parquet(file_path)

parking_tickets = full_parking_tickets

# Check data structure and basic information
if parking_tickets is not None:
    print(parking_tickets.info())
    print(parking_tickets.head())

    # Check for null values
    null_values = parking_tickets.isnull().sum()
    print("Null values in each column:")
    print(null_values)

    # Handle missing values
    parking_tickets['infractiontext'].fillna('Unknown', inplace=True)

    # Confirm no missing values remain
    null_values_after = parking_tickets.isnull().sum()
    print("Null values after cleaning:")
    print(null_values_after)

    # Convert 'EntryDate' to datetime
    parking_tickets['entrydate'] = pd.to_datetime(parking_tickets['entrydate'], errors='coerce')
    
    # Confirm the data types
    print(parking_tickets.dtypes)

    # Check for the number of duplicate rows
    duplicate_rows = parking_tickets.duplicated()
    num_duplicates = duplicate_rows.sum()
    print(f"Number of duplicate rows: {num_duplicates}")

    # Remove duplicate entries if any
    parking_tickets.drop_duplicates(inplace=True)
    
    # Check for any remaining inconsistencies or anomalies
    print("Data quality checks:")
    print(parking_tickets.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1803280 entries, 0 to 1803279
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   block           int64
#  1   street          object
#  2   entrydate       object
#  3   bylaw           int64
#  4   section         object
#  5   status          object
#  6   infractiontext  object
#  7   year            object
#  8   bi_id           int64
# dtypes: int64(3), object(6)
# memory usage: 123.8+ MB
# None
#    block      street   entrydate  bylaw      section status  \
# 0   2000  W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 1   2000  W 41ST AVE  2020-01-04   2952  5(4)(A)(ii)     IS
# 2   5900   EAST BLVD  2020-01-04   2849         21.1     IS
# 3    400  W 64TH AVE  2020-01-04   2849      17.6(B)     IS
# 4    500   ABBOTT ST  2020-01-04   2849         21.1     IS
#
#                                       infractiontext  year    bi_id
# 0  PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649772
# 1  PARK IN A METERED SPACE IF THE PARKING METER H...  2020  3649775
# 2                             STOP IN PASSENGER ZONE  2020  3649778
# 3  PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2020  3649781
# 4                             STOP IN PASSENGER ZONE  2020  3649786
# Null values in each column:
# block                  0
# street                 0
# entrydate              0
# bylaw                  0
# section                0
# status                 0
# infractiontext    955870
# year                   0
# bi_id                  0
# dtype: int64
# Null values after cleaning:
# block             0
# street            0
# entrydate         0
# bylaw             0
# section           0
# status            0
# infractiontext    0
# year              0
# bi_id             0
# dtype: int64
# block                      int64
# street                    object
# entrydate         datetime64[ns]
# bylaw                      int64
# section                   object
# status                    object
# infractiontext            object
# year                      object
# bi_id                      int64
# dtype: object
# Number of duplicate rows: 0
# Data quality checks:
#             block       street            entrydate      bylaw      section  \
# count  1803280.00      1803280              1803280 1803280.00      1803280
# unique        nan          948                 1633        nan          125
# top           nan  RICHARDS ST  2024-06-12 00:00:00        nan  5(4)(A)(ii)
# freq          nan        88214                 1725        nan       678807
# first         nan          NaN  2020-01-02 00:00:00        nan          NaN
# last          nan          NaN  2024-06-30 00:00:00        nan          NaN
# mean      1486.54          NaN                  NaN    2953.11          NaN
# std       1951.83          NaN                  NaN     673.77          NaN
# min          0.00          NaN                  NaN    2849.00          NaN
# 25%        600.00          NaN                  NaN    2849.00          NaN
# 50%       1100.00          NaN                  NaN    2952.00          NaN
# 75%       1900.00          NaN                  NaN    2952.00          NaN
# max      99900.00          NaN                  NaN   13323.00          NaN
#
#          status infractiontext     year      bi_id
# count   1803280        1803280  1803280 1803280.00
# unique        4            130        5        nan
# top          IS        Unknown     2023        nan
# freq    1568039         955870   424371        nan
# first       NaN            NaN      NaN        nan
# last        NaN            NaN      NaN        nan
# mean        NaN            NaN      NaN 4590970.65
# std         NaN            NaN      NaN  576586.91
# min         NaN            NaN      NaN   59169.00
# 25%         NaN            NaN      NaN 4158522.75
# 50%         NaN            NaN      NaN 4610232.50
# 75%         NaN            NaN      NaN 5068702.25
# max         NaN            NaN      NaN 5526982.00

# %% [markdown]
# <h2>Q.1 Please answer the following questions and provide representative data visualizations where applicable.

# %% [markdown]
# <i><b> <h3>a) How many unique hundred-blocks was the rule “Stopping at a place where a traffic sign prohibits stopping” enforced July 2023?

# %%
# Define the specific infraction and the month/year for filtering
specific_infraction = 'STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING'
month = 7
year = 2023

# Filter data for the specific month and year
specific_date_data = full_parking_tickets[
    (full_parking_tickets['entrydate'].dt.month == month) &
    (full_parking_tickets['entrydate'].dt.year == year) &
    (full_parking_tickets['infractiontext'] == specific_infraction)
]

# Create a new column for just the date part (remove the time part)
specific_date_data['EntryDateOnly'] = specific_date_data['entrydate'].dt.date
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
specific_date_data.shape
# Out:
# (4806, 10)

# %%
# Count unique hundred-blocks for a specific infraction in July 2023
unique_blocks = specific_date_data[specific_date_data['infractiontext'] == specific_infraction]['block'].nunique()

print(f"Unique hundred-blocks for '{specific_infraction}' in July 2023: {unique_blocks}")
# Out:
# Unique hundred-blocks for 'STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING' in July 2023: 78

# %% [markdown]
# <i><b> <h3>b) Can you provide a heat map of “Stopping at a place where a traffic sign prohibits stopping” parking tickets across the City in July 2023?

# %%
# Combine Street and Block into a single column
specific_date_data['Street_Block'] = specific_date_data['street'] + ' - ' + specific_date_data['block'].astype(str)

# Calculate the number of tickets for each street-block combination
ticket_counts = specific_date_data[specific_date_data['infractiontext'] == specific_infraction].groupby('Street_Block').size().reset_index(name='Number of Tickets')

# Sort the data to get the top ticketed street-block combinations
top_ticket_counts = ticket_counts.sort_values(by='Number of Tickets', ascending=False).head(20)

# Create a bar plot
plt.figure(figsize=(10, 8))
sns.barplot(data=top_ticket_counts, x='Number of Tickets', y='Street_Block', palette='Blues_d')
plt.title('Top Street-Block Combinations by Number of Tickets')
plt.xlabel('Number of Tickets')
plt.ylabel('Street - Block')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Combine Street and Block into a single column
specific_date_data['Street_Block'] = specific_date_data['street'] + ' - ' + specific_date_data['block'].astype(str)

# Calculate the number of tickets for each street-block combination on each date
ticket_counts = specific_date_data[specific_date_data['infractiontext'] == specific_infraction].groupby(['Street_Block', 'EntryDateOnly']).size().reset_index(name='Number of Tickets')

# Find the street-block combinations with the highest number of tickets
top_ticket_counts = ticket_counts.sort_values(by='Number of Tickets', ascending=False).head(10)

print("Top street-block combinations with the highest number of tickets in July 2023:")
print(top_ticket_counts)

# Heatmap of parking tickets
plt.figure(figsize=(15, 10))
heatmap_data = pd.pivot_table(specific_date_data[specific_date_data['infractiontext'] == specific_infraction], values='bi_id', index='Street_Block', columns='EntryDateOnly', aggfunc='count')

# Define the colormap
colors = sns.color_palette("RdYlGn_r", 256)
cmap = ListedColormap(colors)

sns.heatmap(heatmap_data, cmap=cmap, cbar_kws={'label': 'Number of Tickets'})
plt.title('Heatmap of Parking Tickets in July 2023')
plt.xlabel('Date')
plt.ylabel('Street - Block')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Top street-block combinations with the highest number of tickets in July 2023:
#            Street_Block EntryDateOnly  Number of Tickets
# 2204   W 5TH AVE - 2200    2023-07-08                 52
# 1515  RICHARDS ST - 800    2023-07-26                 36
# 1495  RICHARDS ST - 800    2023-07-06                 31
# 2203   W 5TH AVE - 2100    2023-07-08                 29
# 1514  RICHARDS ST - 800    2023-07-25                 28
# 2209   W 5TH AVE - 2500    2023-07-08                 28
# 1507  RICHARDS ST - 800    2023-07-18                 28
# 1508  RICHARDS ST - 800    2023-07-19                 28
# 1494  RICHARDS ST - 800    2023-07-05                 28
# 1493  RICHARDS ST - 800    2023-07-04                 26

# %% [markdown]
# <i><b><h3> c) How does this change month by month since the beginning of 2020?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# Assuming full_parking_tickets has been loaded and cleaned as shown previously

# Define the specific infraction
specific_infraction = 'STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING'

# Filter data for the specific infraction and from the beginning of 2020
start_date = '2020-01-01'
specific_date_data = full_parking_tickets[
    (full_parking_tickets['entrydate'] >= pd.to_datetime(start_date)) &
    (full_parking_tickets['infractiontext'] == specific_infraction)
]

# Extract year and month from EntryDate
specific_date_data['YearMonth'] = specific_date_data['entrydate'].dt.to_period('M')

# Calculate the number of tickets for each month
monthly_ticket_counts = specific_date_data.groupby('YearMonth').size().reset_index(name='Number of Tickets')

# Convert YearMonth back to datetime for plotting
monthly_ticket_counts['YearMonth'] = monthly_ticket_counts['YearMonth'].dt.to_timestamp()

# Create the line plot
plt.figure(figsize=(15, 7))
plt.plot(monthly_ticket_counts['YearMonth'], monthly_ticket_counts['Number of Tickets'], color='blue', marker='o')

# Find the six highest peaks and six lowest troughs
top_6_high_peaks = monthly_ticket_counts.nlargest(10, 'Number of Tickets')
top_6_low_troughs = monthly_ticket_counts.nsmallest(10, 'Number of Tickets')

# Annotate high peaks
for index, row in top_6_high_peaks.iterrows():
    plt.text(row['YearMonth'], row['Number of Tickets'] + 50, 
             f'{row["Number of Tickets"]}', ha='center', va='bottom', color='red', fontsize=10)

# Annotate low troughs
for index, row in top_6_low_troughs.iterrows():
    plt.text(row['YearMonth'], row['Number of Tickets'] - 50, 
             f'{row["Number of Tickets"]}', ha='center', va='top', color='green', fontsize=10)

# Set quarterly labels on the x-axis
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.title('Number of Parking Tickets Issued per Month for Specific Infraction Since 2020')
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# <i><b><h3> d) What was the most frequent type of parking ticket in the Kensington neighborhood in July 2023?

# %% [markdown]
# To get the neighbourhood data, we need to merge the two datasets. Lets filter the Parking Ticket data to only include July 2023 data first and then merge the two datasets.

# %%
# Define the month/year for filtering
month = 7
year = 2023

# Filter data for the specific month and year
specific_date_data1 = full_parking_tickets[
    (full_parking_tickets['entrydate'].dt.month == month) &
    (full_parking_tickets['entrydate'].dt.year == year)
]

# Create a new column for just the date part (remove the time part)
specific_date_data1['EntryDateOnly'] = specific_date_data1['entrydate'].dt.date
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
specific_date_data1
# Out:
#          block        street  entrydate  bylaw      section status  \
# 338        500     W 8TH AVE 2023-07-10   2952  5(4)(A)(ii)     IS
# 339        500     W 7TH AVE 2023-07-10   2952  5(4)(A)(ii)     IS
# 340       2300        ASH ST 2023-07-10   2952  5(4)(A)(ii)     IS
# 341       3000    HEMLOCK ST 2023-07-10   2849      17.2(K)     IS
# 342       3100  GRANVILLE ST 2023-07-10   2849      17.2(K)     IS
# ...        ...           ...        ...    ...          ...    ...
# 1784973   1600     W 3RD AVE 2023-07-28   2952  5(4)(A)(ii)     IS
# 1784974   1600     W 2ND AVE 2023-07-28   2952  5(4)(A)(ii)     IS
# 1784975   1700     W 2ND AVE 2023-07-28   2952  5(4)(A)(ii)     IS
# 1784976   1600     W 4TH AVE 2023-07-28   2952  5(4)(A)(ii)     IS
# 1784977    500      DAVIE ST 2023-07-28   2849      17.2(K)     IS
#
#                                             infractiontext  year    bi_id  \
# 338      PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650838
# 339      PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650841
# 340      PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650843
# 341      STOP ON ANY STREET OR PORTION OF A STREET DESI...  2023  3650851
# 342      STOP ON ANY STREET OR PORTION OF A STREET DESI...  2023  3650852
# ...                                                    ...   ...      ...
# 1784973  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3901024
# 1784974  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3901026
# 1784975  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3901027
# 1784976  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3901029
# 1784977  STOP ON ANY STREET OR PORTION OF A STREET DESI...  2023  3901032
#
#         EntryDateOnly
# 338        2023-07-10
# 339        2023-07-10
# 340        2023-07-10
# 341        2023-07-10
# 342        2023-07-10
# ...               ...
# 1784973    2023-07-28
# 1784974    2023-07-28
# 1784975    2023-07-28
# 1784976    2023-07-28
# 1784977    2023-07-28
#
# [38842 rows x 10 columns]

# %%
# Filter relevant columns from street data
street_data_filtered1 = street_data[['STREET_NAME', 'LOW_ADDRESS', 'HIGH_ADDRESS', 'NEIGHBORHOOD', 'HBLOCK']]
street_data_filtered1
# Out:
#          STREET_NAME  LOW_ADDRESS  HIGH_ADDRESS       NEIGHBORHOOD  \
# 0      QUESNEL DRIVE      3700.00       3700.00  Dunbar-Southlands
# 1      QUESNEL DRIVE      3700.00       3700.00  Dunbar-Southlands
# 2            GORE AV       900.00       1000.00         Strathcona
# 3            GORE AV       900.00       1000.00         Strathcona
# 4         UNNAMED ST       200.00        300.00         Strathcona
# ...              ...          ...           ...                ...
# 28110      W 47TH AV      2300.00       2300.00         Kerrisdale
# 28111        VINE ST      6300.00       6400.00         Kerrisdale
# 28112        VINE ST      6300.00       6400.00         Kerrisdale
# 28113   BROUGHTON ST       900.00        900.00           West End
# 28114      BRIDGEWAY      3200.00       3200.00   Hastings-Sunrise
#
#                    HBLOCK
# 0      3700 QUESNEL DRIVE
# 1      3700 QUESNEL DRIVE
# 2        900-1000 GORE AV
# 3        900-1000 GORE AV
# 4      200-300 UNNAMED ST
# ...                   ...
# 28110      2300 W 47TH AV
# 28111   6300-6400 VINE ST
# 28112   6300-6400 VINE ST
# 28113    900 BROUGHTON ST
# 28114      3200 BRIDGEWAY
#
# [28115 rows x 5 columns]

# %%
# Create a matching column for blocks within the range
def get_hblock(block, low, high):
    if pd.notnull(low) and pd.notnull(high):
        if low <= block <= high:
            return True
    return False

# Apply function to create a match column
specific_date_data1['Match'] = specific_date_data1.apply(
    lambda x: street_data_filtered1[
        (street_data_filtered1['STREET_NAME'] == x['street']) &
        (street_data_filtered1['LOW_ADDRESS'] <= x['block']) &
        (street_data_filtered1['HIGH_ADDRESS'] >= x['block'])
    ].any(axis=None), axis=1
)
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Merge datasets
merged_data1 = pd.merge(
    specific_date_data1, street_data_filtered1,
    left_on=['street', 'block'], right_on=['STREET_NAME', 'LOW_ADDRESS'],
    how='left'
)

# Display merged data
merged_data1.head()
# Out:
#    block     street  entrydate  bylaw      section status  \
# 0    500  W 8TH AVE 2023-07-10   2952  5(4)(A)(ii)     IS
# 1    500  W 7TH AVE 2023-07-10   2952  5(4)(A)(ii)     IS
# 2   2300     ASH ST 2023-07-10   2952  5(4)(A)(ii)     IS
# 3   2300     ASH ST 2023-07-10   2952  5(4)(A)(ii)     IS
# 4   2300     ASH ST 2023-07-10   2952  5(4)(A)(ii)     IS
#
#                                       infractiontext  year    bi_id  \
# 0  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650838
# 1  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650841
# 2  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650843
# 3  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650843
# 4  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3650843
#
#   EntryDateOnly  Match STREET_NAME  LOW_ADDRESS  HIGH_ADDRESS NEIGHBORHOOD  \
# 0    2023-07-10  False         NaN          nan           nan          NaN
# 1    2023-07-10  False         NaN          nan           nan          NaN
# 2    2023-07-10   True      ASH ST      2300.00       2300.00     Fairview
# 3    2023-07-10   True      ASH ST      2300.00       2300.00     Fairview
# 4    2023-07-10   True      ASH ST      2300.00       2300.00     Fairview
#
#         HBLOCK
# 0          NaN
# 1          NaN
# 2  2300 ASH ST
# 3  2300 ASH ST
# 4  2300 ASH ST

# %%
#Dealing with duplicated rows:

#Identify duplicated rows
duplicates = merged_data1.duplicated()

#Count the number of duplicated rows
num_duplicates = duplicates.sum()
print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 24847

# %%
merged_data1.shape
# Out:
# (64691, 16)

# %%
#Drop duplicated rows based on 'BI_ID'
merged_data1 = merged_data1.drop_duplicates(subset='bi_id')

# %%
merged_data1.shape
# Out:
# (38842, 16)

# %%
# Filter records containing 'Kensington' in the 'NEIGHBORHOOD' column, case insensitive
kensington_tickets = merged_data1[merged_data1['NEIGHBORHOOD'].str.contains('Kensington', case=False, na=False)]
kensington_tickets
# Out:
#        block            street  entrydate  bylaw      section status  \
# 423     4000  PRINCE ALBERT ST 2023-07-10   2849      17.6(B)     IS
# 713     4700         LITTLE ST 2023-07-03   2849      17.2(C)     IS
# 789     4500      GLADSTONE ST 2023-07-13   2849      17.6(B)     IS
# 875     3100    VICTORIA DRIVE 2023-07-13   2849      17.6(F)     VA
# 913     3900         KNIGHT ST 2023-07-13   2849      17.2(K)     IS
# ...      ...               ...        ...    ...          ...    ...
# 63807   3200         FRASER ST 2023-07-20   2849         17.3     IS
# 64000   2600  COMMERCIAL DRIVE 2023-07-20   2952  5(4)(A)(ii)     IS
# 64004   2600  COMMERCIAL DRIVE 2023-07-20   2952  5(4)(A)(ii)     IS
# 64043   3200    VICTORIA DRIVE 2023-07-20   2849      17.6(B)     IS
# 64128    700          KINGSWAY 2023-07-28   2849      17.6(E)     VA
#
#                                           infractiontext  year    bi_id  \
# 423    PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2023  3655785
# 713               STOP WITHIN 5 METRES OF A FIRE HYDRANT  2023  3656369
# 789    PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2023  4092733
# 875    PARK ON A STREET ABUTTING RESIDENTIAL OR COMME...  2023  4092902
# 913    STOP ON ANY STREET OR PORTION OF A STREET DESI...  2023  4092962
# ...                                                  ...   ...      ...
# 63807  STOP ON ANY PORTION OF A STREET DESIGNATED AS ...  2023  3699625
# 64000  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3699991
# 64004  PARK IN A METERED SPACE IF THE PARKING METER H...  2023  3699992
# 64043  PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICT...  2023  3700054
# 64128  PARK ON ANY PORTION OF A STREET FOR A LONGER P...  2023  3899109
#
#       EntryDateOnly  Match       STREET_NAME  LOW_ADDRESS  HIGH_ADDRESS  \
# 423      2023-07-10   True  PRINCE ALBERT ST      4000.00       4000.00
# 713      2023-07-03   True         LITTLE ST      4700.00       4700.00
# 789      2023-07-13   True      GLADSTONE ST      4500.00       4500.00
# 875      2023-07-13   True    VICTORIA DRIVE      3100.00       3100.00
# 913      2023-07-13   True         KNIGHT ST      3900.00       3900.00
# ...             ...    ...               ...          ...           ...
# 63807    2023-07-20   True         FRASER ST      3200.00       3200.00
# 64000    2023-07-20   True  COMMERCIAL DRIVE      2600.00       2600.00
# 64004    2023-07-20   True  COMMERCIAL DRIVE      2600.00       2600.00
# 64043    2023-07-20   True    VICTORIA DRIVE      3200.00       3300.00
# 64128    2023-07-28   True          KINGSWAY       700.00        700.00
#
#                    NEIGHBORHOOD                    HBLOCK
# 423    Kensington-Cedar Cottage     4000 PRINCE ALBERT ST
# 713    Kensington-Cedar Cottage            4700 LITTLE ST
# 789    Kensington-Cedar Cottage         4500 GLADSTONE ST
# 875    Kensington-Cedar Cottage       3100 VICTORIA DRIVE
# 913    Kensington-Cedar Cottage            3900 KNIGHT ST
# ...                         ...                       ...
# 63807  Kensington-Cedar Cottage            3200 FRASER ST
# 64000  Kensington-Cedar Cottage     2600 COMMERCIAL DRIVE
# 64004  Kensington-Cedar Cottage     2600 COMMERCIAL DRIVE
# 64043  Kensington-Cedar Cottage  3200-3300 VICTORIA DRIVE
# 64128  Kensington-Cedar Cottage              700 KINGSWAY
#
# [439 rows x 16 columns]

# %%
# Determine the most frequent ticket type
most_frequent_ticket = kensington_tickets['infractiontext'].value_counts().idxmax()

# Display the result
print(f"The most frequent type of parking ticket in the Kensington neighborhood in July 2023 was: {most_frequent_ticket}")
# Out:
# The most frequent type of parking ticket in the Kensington neighborhood in July 2023 was: STOP ON ANY STREET OR PORTION OF A STREET DESIGNATED AS A PRIORITY CONGESTION MANAGEMENT ROADWAY DURING THE TIME STOPPING IS PROHIBITED

# %%
# Determine the most frequent ticket type
kensington_tickets['infractiontext'].value_counts()
# Out:
# STOP ON ANY STREET OR PORTION OF A STREET DESIGNATED AS A PRIORITY CONGESTION MANAGEMENT ROADWAY DURING THE TIME STOPPING IS PROHIBITED                                                                      114
# PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICTS PARKING, EXCEPT IN ACCORDANCE WITH SUCH RESTRICTION                                                                                                           41
# STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING                                                                                                                                                       38
# STOP WITHIN 6 METRES OF THE NEAREST EDGE OF THE CLOSEST SIDEWALK ON AN INTERSECTING STREET                                                                                                                    37
# PARK IN A METERED SPACE IF THE PARKING METER HEAD DISPLAYS FOUR FLASHING ZEROS IN A WINDOW                                                                                                                    34
# PARK ON A STREET ABUTTING RESIDENTIAL OR COMMERCIAL PREMISES FOR MORE THAN 3 HRS BETWEEN 8:00A.M. AND 6:00 P.M.                                                                                               22
# STOP ON ANY PORTION OF A STREET DESIGNATED AS A BUS STOP                                                                                                                                                      19
# LARGE VEHICLE - BE PARKED ON A STREET ABUTTING PROPERTY USED FOR A PUBLIC PARK,SCHOOL,CHURCH OR RESIDENTIAL PURPOSES                                                                                          17
# STOP WITHIN 6 METRES OF THE APPROACH SIDE OF A STOP SIGN                                                                                                                                                      12
# STOP WITHIN 5 METRES OF A FIRE HYDRANT                                                                                                                                                                        12
# NO PERSON SHALL PLACE, LEAVE, ABANDON ANY DERELICT MOTOR VEHICLE ON ANY STREET                                                                                                                                10
# PARK ON ANY PORTION OF A STREET FOR A LONGER PERIOD OF TIME THAN INDICATED ON ANY TRAFFIC SIGN GOVERNING THAT PORTION OF A STREET                                                                              9
# STOP IN FRONT OF OR WITHIN 1.5 METRES OF THE NEAREST SIDE OF A PRIVATE ROAD, BOULEVARD CROSSING OR SIDEWALK CROSSING                                                                                           7
# STOP IN COMMERCIAL LOADING ZONE                                                                                                                                                                                7
# STOP OR PARK OTHER THAN HEADED IN THE DIRECTION OF TRAFFIC                                                                                                                                                     6
# AUTOMATIC WATERING OF RESIDENTIAL LAWN AT EVEN-NUMBERED ADDRESSES OUTSIDE PERMITTED HOURS - STAGE 1                                                                                                            6
# STOP ON EITHER SIDE OF A LANE WHICH ABUTS COMMERCIALLY USED PROPERTY                                                                                                                                           6
# PARK AT A PLACE ON A STREET WHERE A TRAFFIC SIGN PROHIBITS PARKING                                                                                                                                             4
# STOP ON ANY PORTION OF A STREET INDICATED BY A SIGN OR OTHER MARKER AS RESERVED FOR ONE OR MORE CLASS OF VEHICLE, EXCEPT FOR RECOGNIZED VEHICLES OF THAT CLASS                                                 4
# LARGE VEHICLE - BE PARKED ON A STREET BETWEEN THE HOURS OF 10 PM AND 6 AM OF THE FOLLOWING DAY                                                                                                                 4
# MANUAL WATERING OF RESIDENTIAL LAWN AT EVEN-NUMBERED ADDRESSES OUTSIDE PERMITTED HOURS - STAGE 1                                                                                                               3
# STOP OR PARK OTHER THAN WITH THE CURBSIDE WHEELS OF THE VEHICLE WITHIN 30 CM OF THE CURB OR EDGE OF THE ROADWAY                                                                                                3
# STOP IN LOADING ZONE                                                                                                                                                                                           3
# STOP WITHIN 6 METRES OF EITHER SIDE OF A CROSSWALK, EXCEPT FOR THE DRIVER OF A MOTORCYCLE OR MOTOR ASSISTED CYCLE WHO IS PARKING IN A CLEARANCE PARKING AREA OR A BICYCLE RIDER PARKING AT A BICYCLE RACK      2
# STOP WITHIN 9 METRES OF THE NEAREST EDGE OF THE PAVEMENT ON AN INTERSECTING STREET WHERE NO SIDEWALK EXISTS                                                                                                    2
# STOP IN PASSENGER ZONE                                                                                                                                                                                         2
# STOP ON A LANE WITHIN AN AREA 1.5M FROM EITHER SIDE AND 5.5M IN FRONT OF A DRIVE -WAY OR PRIVATE ROAD ADJOINING SUCH LANE                                                                                      2
# STOP WITHIN 2 METRES OF THE APPROACH SIDE OF THE NEAREST EDGE OF THE CLOSEST SIDEWALK ON AN INTERSECTING STREET                                                                                                2
# STOP ON BOULEVARD                                                                                                                                                                                              1
# MANUAL WATERING OF RESIDENTIAL LAWN AT ODD-NUMBERED ADDRESSES OUTSIDE PERMITTED HOURS - STAGE 1                                                                                                                1
# STOP ON A LANE IN SUCH A MANNER AS TO LEAVE AVAILABLE LESS THAN 3M OF USABLE LANE FOR FREE MOVEMENT OF VEHICLES                                                                                                1
# LARGE VEHICLE - BE PARKED ON A STREET ABUTTING PREMISES USED FOR BUSINESS PURPOSES FOR MORE THAN THREE HOURS                                                                                                   1
# WASTING WATER - THE FREE DISCHARGE OR FLOW OF WATER FROM PREMISES                                                                                                                                              1
# STOP WITHIN 1.5 METRES OF THAT PORTION OF AN INTERSECTING LANE THAT IS USEABLE FOR TRAVEL                                                                                                                      1
# CAUSE, ALLOW OR PERMIT A VEHICLE TO IDLE FOR MORE THAN THREE CONSECUTIVE MINUTES IN A 60 MINUTE PERIOD                                                                                                         1
# AUTOMATIC WATERING OF RESIDENTIAL LAWN AT ODD-NUMBERED ADDRESSES OUTSIDE PERMITTED HOURS - STAGE 1                                                                                                             1
# PARK ON A STREET WHERE A TRAFFIC SIGN RESTRICTS PARKING, EXCEPT IN ACCORDANCE WITH SUCH RESTRICTION..                                                                                                          1
# WASTING WATER - USE OF A WATER HOSE WHICH IS NOT EQUIPPED WITH AN AUTOMATIC SHUT-OFF DEVICE                                                                                                                    1
# PARK IN A METERED SPACE IF THE TIME RECORDED BY THE OPERATOR UNDER THE PAY BY PHONE OR PAY BY LICENCE PLATE OPTION HAS EXPIRED                                                                                 1
# Name: infractiontext, dtype: int64

# %% [markdown]
# <h2>Q.2 The supervisor mentioned that they spend ~1 hr / week summarizing this data and would like to automate it. Please provide python code that would allow you to automate this report. Show all your steps and results including data loading, cleaning, analysis

# %% [markdown]
# <h3>Data Loading, Cleaning & Analysis:

# %% [markdown]
# <h2>Q3. Please include a short discussion (max 2 paragraphs)

# %% [markdown]
# <h3>a) How would you go about building a forecast of where enforcement is needed?

# %% [markdown]
# <h3> b) What additional data would you include in the report to facilitate more meaningful insights?

# %% [markdown]
# To facilitate more meaningful insights, I would include additional data that could impact parking patterns and enforcement needs. This data would enhance the analysis and help in making more informed decisions:
#
#    <b> Traffic Flow Data:</b>
#         Information on traffic volume and flow can provide insights into areas with high vehicle congestion, which might correlate with higher parking violations.
#
#    <b>Special Events Calendar:</b>
#         Data on special events (e.g., concerts, sports events, festivals) can help predict temporary spikes in parking violations around event locations.
#
#    <b>Weather Data:</b>
#         Weather conditions can influence parking behavior. For instance, people might park illegally to avoid walking long distances in bad weather.
#
#    <b>Demographic Data:</b>
#         Demographic information, such as population density and the presence of commercial or residential areas, can provide context on why certain areas experience more violations.
#
#    <b>Public Transit Data:</b>
#         Availability and proximity of public transit options might affect parking patterns. Areas with limited public transit might see more parking infractions as people rely more on personal vehicles.
#
#    <b>Construction and Roadwork Schedules:</b>
#         Information on ongoing or planned construction projects can help predict temporary changes in parking availability and potential increases in violations in nearby areas.
#
# By incorporating these additional datasets, the analysis would provide a more comprehensive understanding of parking patterns and enforcement needs, leading to more effective and targeted enforcement strategies.

# %% [markdown]
# <h4> Generate a Bar Plot for number of tickets for a specific infraction for the specific time period

# %%
# Define the specific infraction and the month/year for filtering
specific_infraction = 'STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING'
month = 7
year = 2023

# Filter data for the specific month and year
specific_date_data = full_parking_tickets[
    (full_parking_tickets['entrydate'].dt.month == month) &
    (full_parking_tickets['entrydate'].dt.year == year) &
    (full_parking_tickets['infractiontext'] == specific_infraction)
]

# Create a new column for just the date part (remove the time part)
specific_date_data['EntryDateOnly'] = specific_date_data['entrydate'].dt.date


# Calculate the number of tickets for each date
ticket_counts = specific_date_data.groupby('EntryDateOnly').size().reset_index(name='Number of Tickets')

# Normalize the number of tickets for color mapping
norm = plt.Normalize(ticket_counts['Number of Tickets'].min(), ticket_counts['Number of Tickets'].max())
cmap = plt.get_cmap('YlOrRd')

# Create the bar plot with gradient colors
plt.figure(figsize=(15, 7))
bar_colors = cmap(norm(ticket_counts['Number of Tickets']))
bars = plt.bar(ticket_counts['EntryDateOnly'], ticket_counts['Number of Tickets'], color=bar_colors)

# Add annotations for the number of tickets above each bar with smaller font size and better spacing
for i in range(len(ticket_counts)):
    plt.text(ticket_counts['EntryDateOnly'][i], ticket_counts['Number of Tickets'][i] + 2, 
             str(ticket_counts['Number of Tickets'][i]), ha='center', va='bottom', fontsize=8)

plt.title('Number of Parking Tickets per Day in July 2023 (for STOPPING AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING)')
plt.xlabel('Date')
plt.ylabel('Number of Tickets')

# Reduce the number of x-axis labels by setting an interval
plt.xticks(ticket_counts['EntryDateOnly'][::2], rotation=45, ha='right', fontsize=8)

plt.tight_layout()

# Adding a color bar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
plt.colorbar(sm, label='Number of Tickets')

plt.show()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# <h2>Geomapping the Parking Tickets Data (July 2023) with 'Street Trees' Data :

# %% [markdown]
# https://opendata.vancouver.ca/explore/dataset/street-trees/information/?disjunctive.species_name&disjunctive.common_name&disjunctive.on_street&disjunctive.neighbourhood_name

# %%
 # Load data
street_trees_data = pd.read_csv('street-trees.csv', delimiter=';', encoding='utf-8', error_bad_lines=False)
street_trees_data.head(10)
# Out:
#    TREE_ID  CIVIC_NUMBER   STD_STREET GENUS_NAME   SPECIES_NAME CULTIVAR_NAME  \
# 0    96658          1864  MATTHEWS AV     BETULA        PENDULA           NaN
# 1    96663          1902  MATTHEWS AV     PRUNUS      SARGENTII        RANCHO
# 2    96664          1902  MATTHEWS AV     PRUNUS     CERASIFERA  ATROPURPUREA
# 3    96671          1950  MATTHEWS AV     PRUNUS     CERASIFERA  ATROPURPUREA
# 4    96672          1955  MATTHEWS AV      ULMUS      AMERICANA           NaN
# 5    96674          1955  MATTHEWS AV      ULMUS      AMERICANA           NaN
# 6    96680          1998  MATTHEWS AV     PRUNUS     CERASIFERA  ATROPURPUREA
# 7    96687          2688    W 39TH AV   AESCULUS  HIPPOCASTANUM           NaN
# 8    96700          3321   MAYFAIR AV      ULMUS      AMERICANA           NaN
# 9    96703          3335    W 39TH AV     CORNUS      NUTTALLII           NaN
#
#              COMMON_NAME ASSIGNED ROOT_BARRIER PLANT_AREA  ...      ON_STREET  \
# 0   EUROPEAN WHITE BIRCH        N            N          8  ...  PINE CRESCENT
# 1  RANCHO SARGENT CHERRY        N            N          8  ...    MATTHEWS AV
# 2           PISSARD PLUM        N            N          8  ...    MATTHEWS AV
# 3           PISSARD PLUM        N            N          8  ...    MATTHEWS AV
# 4           AMERICAN ELM        N            N          8  ...    MATTHEWS AV
# 5           AMERICAN ELM        N            N          8  ...    MATTHEWS AV
# 6           PISSARD PLUM        N            N          8  ...    MATTHEWS AV
# 7   COMMON HORSECHESTNUT        N            N          7  ...   TRAFALGAR ST
# 8           AMERICAN ELM        N            N         10  ...     MAYFAIR AV
# 9        PACIFIC DOGWOOD        N            N          N  ...     MAYFAIR AV
#
#   NEIGHBOURHOOD_NAME STREET_SIDE_NAME HEIGHT_RANGE_ID  HEIGHT_RANGE DIAMETER  \
# 0        SHAUGHNESSY              ODD               5     50' - 60'    17.00
# 1        SHAUGHNESSY             EVEN               2     20' - 30'    10.00
# 2        SHAUGHNESSY             EVEN               2     20' - 30'    10.00
# 3        SHAUGHNESSY             EVEN               2     20' - 30'    10.50
# 4        SHAUGHNESSY              ODD               8     80' - 90'    27.50
# 5        SHAUGHNESSY              ODD               7     70' - 80'    27.50
# 6        SHAUGHNESSY             EVEN               2     20' - 30'    11.00
# 7      ARBUTUS RIDGE             EVEN               4     40' - 50'    20.00
# 8  DUNBAR-SOUTHLANDS              ODD               8     80' - 90'    42.00
# 9  DUNBAR-SOUTHLANDS             EVEN               3     30' - 40'    18.00
#
#    CURB DATE_PLANTED                                               Geom  \
# 0     Y          NaN  {"coordinates": [-123.147427, 49.250793], "typ...
# 1     Y          NaN  {"coordinates": [-123.149101, 49.251123], "typ...
# 2     Y          NaN  {"coordinates": [-123.149295, 49.251156], "typ...
# 3     Y          NaN  {"coordinates": [-123.14987, 49.25131], "type"...
# 4     Y          NaN  {"coordinates": [-123.149743, 49.251378], "typ...
# 5     Y          NaN  {"coordinates": [-123.14945, 49.251291], "type...
# 6     Y          NaN  {"coordinates": [-123.150413, 49.25155], "type...
# 7     Y          NaN  {"coordinates": [-123.165726, 49.23632], "type...
# 8     N          NaN  {"coordinates": [-123.17913, 49.23694], "type"...
# 9     N          NaN  {"coordinates": [-123.17953, 49.2368], "type":...
#
#              geo_point_2d
# 0  49.250793, -123.147427
# 1  49.251123, -123.149101
# 2  49.251156, -123.149295
# 3    49.25131, -123.14987
# 4  49.251378, -123.149743
# 5   49.251291, -123.14945
# 6   49.25155, -123.150413
# 7   49.23632, -123.165726
# 8    49.23694, -123.17913
# 9     49.2368, -123.17953
#
# [10 rows x 21 columns]

# %%
street_trees_data.shape
# Out:
# (152148, 21)

# %%
# Check for duplicated rows
duplicates = street_trees_data.duplicated()

# Print the duplicated rows
print(street_trees_data[duplicates])

# Count the number of duplicated rows
num_duplicated_rows = duplicates.sum()
print(f"Number of duplicated rows: {num_duplicated_rows}")
# Out:
# Empty DataFrame
# Columns: [TREE_ID, CIVIC_NUMBER, STD_STREET, GENUS_NAME, SPECIES_NAME, CULTIVAR_NAME, COMMON_NAME, ASSIGNED, ROOT_BARRIER, PLANT_AREA, ON_STREET_BLOCK, ON_STREET, NEIGHBOURHOOD_NAME, STREET_SIDE_NAME, HEIGHT_RANGE_ID, HEIGHT_RANGE, DIAMETER, CURB, DATE_PLANTED, Geom, geo_point_2d]
# Index: []
#
# [0 rows x 21 columns]
# Number of duplicated rows: 0

# %%
#Inspecting for null values

null_street_trees_data = street_trees_data.isnull().sum()
print("Null values in each column:")
print(null_street_trees_data)
# Out:
# Null values in each column:
# TREE_ID                   0
# CIVIC_NUMBER              0
# STD_STREET                0
# GENUS_NAME                0
# SPECIES_NAME              0
# CULTIVAR_NAME         71449
# COMMON_NAME               0
# ASSIGNED                  0
# ROOT_BARRIER              0
# PLANT_AREA             1444
# ON_STREET_BLOCK           0
# ON_STREET                 0
# NEIGHBOURHOOD_NAME        0
# STREET_SIDE_NAME          0
# HEIGHT_RANGE_ID           0
# HEIGHT_RANGE              0
# DIAMETER                  0
# CURB                      0
# DATE_PLANTED          78382
# Geom                   4210
# geo_point_2d           4210
# dtype: int64

# %%
# Define the specific infraction and the month/year for filtering
specific_infraction = 'STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS STOPPING'
month = 7
year = 2023

# Filter data for the specific month and year
specific_date_data2 = full_parking_tickets[
    (full_parking_tickets['entrydate'].dt.month == month) &
    (full_parking_tickets['entrydate'].dt.year == year) &
    (full_parking_tickets['infractiontext'] == specific_infraction)
]

# Create a new column for just the date part (remove the time part)
specific_date_data2['EntryDateOnly'] = specific_date_data2['entrydate'].dt.date
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Standardize street names in both datasets
specific_date_data2['street'] = specific_date_data2['street'].str.upper().str.strip()
street_trees_data['ON_STREET'] = street_trees_data['ON_STREET'].str.upper().str.strip()
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Filter relevant columns from street data
street_trees_filtered = street_trees_data[['ON_STREET_BLOCK', 'ON_STREET', 'Geom', 'geo_point_2d']]

# %%
# Merge datasets
merged_data2 = pd.merge(
    specific_date_data2, street_trees_filtered,
    left_on=['street', 'block'], right_on=['ON_STREET', 'ON_STREET_BLOCK'],
    how='left'
)

# Display merged data
merged_data2.head()
# Out:
#    block       street  entrydate  bylaw  section status  \
# 0    800  RICHARDS ST 2023-07-10   2849  17.1(B)     VA
# 1    800  RICHARDS ST 2023-07-10   2849  17.1(B)     VA
# 2    800  RICHARDS ST 2023-07-10   2849  17.1(B)     VA
# 3    800  RICHARDS ST 2023-07-10   2849  17.1(B)     VA
# 4    800  RICHARDS ST 2023-07-10   2849  17.1(B)     VA
#
#                                       infractiontext  year    bi_id  \
# 0  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
# 1  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
# 2  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
# 3  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
# 4  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
#
#   EntryDateOnly  ON_STREET_BLOCK    ON_STREET  \
# 0    2023-07-10           800.00  RICHARDS ST
# 1    2023-07-10           800.00  RICHARDS ST
# 2    2023-07-10           800.00  RICHARDS ST
# 3    2023-07-10           800.00  RICHARDS ST
# 4    2023-07-10           800.00  RICHARDS ST
#
#                                                 Geom            geo_point_2d
# 0  {"coordinates": [-123.118085, 49.27985], "type...   49.27985, -123.118085
# 1  {"coordinates": [-123.118863, 49.279336], "typ...  49.279336, -123.118863
# 2                                                NaN                     NaN
# 3  {"coordinates": [-123.119228, 49.279106], "typ...  49.279106, -123.119228
# 4  {"coordinates": [-123.118106, 49.280025], "typ...  49.280025, -123.118106

# %%
merged_data2.shape
# Out:
# (60129, 14)

# %%
# Check for null values in tickets data
print(merged_data2.isnull().sum())
# Out:
# block                 0
# street                0
# entrydate             0
# bylaw                 0
# section               0
# status                0
# infractiontext        0
# year                  0
# bi_id                 0
# EntryDateOnly         0
# ON_STREET_BLOCK    1645
# ON_STREET          1645
# Geom               6596
# geo_point_2d       6596
# dtype: int64

# %%
# Drop duplicates based on 'BI_ID'
unique_data = merged_data2.drop_duplicates(subset='bi_id')

# View the resulting DataFrame
print(unique_data)
# Out:
#        block            street  entrydate  bylaw  section status  \
# 0        800       RICHARDS ST 2023-07-10   2849  17.1(B)     VA
# 25      1900        W 42ND AVE 2023-07-10   2849  17.1(B)     IS
# 26      1700          DAVIE ST 2023-07-10   2849  17.1(B)     IS
# 34      1000         DENMAN ST 2023-07-10   2849  17.1(B)     IS
# 53       100          DAVIE ST 2023-07-10   2849  17.1(B)     IS
# ...      ...               ...        ...    ...      ...    ...
# 60041   1600  COMMERCIAL DRIVE 2023-07-28   2849  17.1(B)     IS
# 60049   1000     W HASTINGS ST 2023-07-28   2849  17.1(B)     IS
# 60083   1000     W HASTINGS ST 2023-07-28   2849  17.1(B)     IS
# 60117   4300         WATSON ST 2023-07-28   2849  17.1(B)     IS
# 60118   1900         BALSAM ST 2023-07-28   2849  17.1(B)     IS
#
#                                           infractiontext  year    bi_id  \
# 0      STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650923
# 25     STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650928
# 26     STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650941
# 34     STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650944
# 53     STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3650977
# ...                                                  ...   ...      ...
# 60041  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3900543
# 60049  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3900969
# 60083  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3900970
# 60117  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3900985
# 60118  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2023  3901015
#
#       EntryDateOnly  ON_STREET_BLOCK         ON_STREET  \
# 0        2023-07-10           800.00       RICHARDS ST
# 25       2023-07-10              nan               NaN
# 26       2023-07-10          1700.00          DAVIE ST
# 34       2023-07-10          1000.00         DENMAN ST
# 53       2023-07-10           100.00          DAVIE ST
# ...             ...              ...               ...
# 60041    2023-07-28          1600.00  COMMERCIAL DRIVE
# 60049    2023-07-28          1000.00     W HASTINGS ST
# 60083    2023-07-28          1000.00     W HASTINGS ST
# 60117    2023-07-28              nan               NaN
# 60118    2023-07-28          1900.00         BALSAM ST
#
#                                                     Geom  \
# 0      {"coordinates": [-123.118085, 49.27985], "type...
# 25                                                   NaN
# 26     {"coordinates": [-123.140618, 49.286387], "typ...
# 34     {"coordinates": [-123.138967, 49.289044], "typ...
# 53                                                   NaN
# ...                                                  ...
# 60041  {"coordinates": [-123.069748, 49.270039], "typ...
# 60049  {"coordinates": [-123.118955, 49.287617], "typ...
# 60083  {"coordinates": [-123.118955, 49.287617], "typ...
# 60117                                                NaN
# 60118  {"coordinates": [-123.159933, 49.268874], "typ...
#
#                  geo_point_2d
# 0       49.27985, -123.118085
# 25                        NaN
# 26     49.286387, -123.140618
# 34     49.289044, -123.138967
# 53                        NaN
# ...                       ...
# 60041  49.270039, -123.069748
# 60049  49.287617, -123.118955
# 60083  49.287617, -123.118955
# 60117                     NaN
# 60118  49.268874, -123.159933
#
# [4806 rows x 14 columns]

# %%
# Check for null values in tickets data
print(unique_data.isnull().sum())
# Out:
# block                 0
# street                0
# entrydate             0
# bylaw                 0
# section               0
# status                0
# infractiontext        0
# year                  0
# bi_id                 0
# EntryDateOnly         0
# ON_STREET_BLOCK    1645
# ON_STREET          1645
# Geom               1839
# geo_point_2d       1839
# dtype: int64

# %%
unique_data.shape
# Out:
# (4806, 14)

# %%
# Split the 'geo_point_2d' column into 'Latitude' and 'Longitude' columns
unique_data[['Latitude', 'Longitude']] = unique_data['geo_point_2d'].str.split(', ', expand=True)
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# Convert the 'Latitude' and 'Longitude' columns to numeric types
unique_data['Latitude'] = pd.to_numeric(unique_data['Latitude'])
unique_data['Longitude'] = pd.to_numeric(unique_data['Longitude'])
# Out:
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\12366\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import folium
from folium.plugins import HeatMap

# Drop rows with missing coordinates
unique_data = unique_data.dropna(subset=['Latitude', 'Longitude'])

# Create a list of coordinates
heat_data = [[row['Latitude'], row['Longitude']] for index, row in unique_data.iterrows()]

# Create a heatmap
map_vancouver = folium.Map(location=[49.2827, -123.1207], zoom_start=12)
HeatMap(heat_data).add_to(map_vancouver)

# Save and display the map
map_vancouver.save('heatmap.html')
